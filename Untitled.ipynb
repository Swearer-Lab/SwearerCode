# %%
from pathlib import Path
import datetime
import sys
import scipy.integrate
import random
import math

# %config InlineBackend.figure_format='retina'
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import pandas as pd

import matplotlib as mpl
import matplotlib.font_manager as fm

import seaborn as sns

import spectrochempy as scp


mpl.rc('text', usetex=False)


import os
# Out:
#
#     <div>
#     <table>
#     <tr>
#     <td>
#
#     <img src='...'
#          style='height:25px; border-radius:12px; display:inline-block; float:left; vertical-align:middle'>
#     </img>
#
#     </td>
#     <td>
#
#     &nbsp;&nbsp;<span style='font-size:12px'>SpectroChemPy's API - v.0.6.6<br/>© Copyright 2014-2024 - A.Travert & C.Fernandez @ LCS</span>
#
#     </td>
#     </tr>
#     </table>
#     </div>

# %%
testspa2 = scp.ones([2,2], dtype = "float64", units = "s")
#testspa =scp.read("FTIR_230925_PtAl2O310_90KCl_CO_5s_300nm700_50mW.txt")
#testspa = scp.read_omnic("FTIR_230925_PtAl2O310_90KCl_CO_5s0362.spa")
testspa2
#testspa
filename = scp.save(testspa2)

# %%
# Create a dataset
df = pd.DataFrame(np.random.random((5,5)), columns=["a","b","c","d","e"])

# Default heatmap
p1 = sns.heatmap(df)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def reality_check(filename):
    
    try:
        x = scp.read_omnic(filename)
    except OSError:
        if filename[-4:] == "0000":
            print("Could not open/read file:", filename)
            exit()
        else:
            return False
    else:
        return True

# %%
name = 'FTIR_231027_PtAl2O310_95KBr_1%CO_500s_550_150m_49mW_2'
i_str = "0000"
reality_check(name + i_str +'.spa')
# Out:
# False

# %%
name = 'FTIR_231027_PtAl2O310_95KBr_1%CO_500s_550_150m_49mW_2' # Base name for your series, before the number of the split file
i = 0 
i_str = f'{str(i):0>4}'

while os.path.exists(name + i_str +'.spa'):
    i += 1
    i_str = f'{str(i):0>4}'
    print(i_str)
# Out:
# 0001
# 0002
# 0003
# 0004
# 0005
# 0006
# 0007
# 0008
# 0009
# 0010
# 0011
# 0012
# 0013
# 0014
# 0015
# 0016
# 0017
# 0018
# 0019
# 0020
# 0021
# 0022
# 0023
# 0024
# 0025
# 0026
# 0027
# 0028
# 0029
# 0030
# 0031
# 0032
# 0033
# 0034
# 0035
# 0036
# 0037
# 0038
# 0039
# 0040
# 0041
# 0042
# 0043
# 0044
# 0045
# 0046
# 0047
# 0048
# 0049
# 0050
# 0051
# 0052
# 0053
# 0054
# 0055
# 0056
# 0057
# 0058
# 0059
# 0060
# 0061
# 0062
# 0063
# 0064
# 0065
# 0066
# 0067
# 0068
# 0069
# 0070
# 0071
# 0072
# 0073
# 0074
# 0075
# 0076
# 0077
# 0078
# 0079
# 0080
# 0081
# 0082
# 0083
# 0084
# 0085
# 0086
# 0087
# 0088
# 0089
# 0090
# 0091
# 0092
# 0093
# 0094
# 0095
# 0096
# 0097
# 0098
# 0099
# 0100
# 0101
# 0102
# 0103
# 0104
# 0105
# 0106
# 0107
# 0108
# 0109
# 0110
# 0111
# 0112
# 0113
# 0114
# 0115
# 0116
# 0117
# 0118
# 0119
# 0120
# 0121
# 0122
# 0123
# 0124
# 0125
# 0126
# 0127
# 0128
# 0129
# 0130
# 0131
# 0132
# 0133
# 0134
# 0135
# 0136
# 0137
# 0138
# 0139
# 0140
# 0141
# 0142
# ...

# %%
testspa.history
# Out:
# ['2023-10-23 00:17:37-05:00> 2023-10-22 23:59:34-05:00> 2023-10-22 23:00:29-05:00> 2023-10-22 22:52:23-05:00> 2023-10-22 18:47:36-05:00> 2023-10-22 18:28:00-05:00> 2023-09-28 19:10:12-05:00> Created by concatenate']

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2023, 10, 31, 14, 57, 1, 351759)

# %%
datetime.datetime.utcnow()
# Out:
# datetime.datetime(2023, 10, 31, 19, 57, 5, 640673)
